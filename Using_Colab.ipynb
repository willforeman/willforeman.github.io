# %% [markdown]
# This is a quick guide to take you through the basics of using Colaboratory. It is an interactive environment that allows you to write and run Python code from a browser.
#
# To open a new notebook that you can edit, go to File and then New notebook.
#
# Sections of text or code in Colab are called cells.
# To add a code snippet, click the + Code button in the top left. It will appear as a cell, like the code below, and you will be able to edit it. Press the play button on the left of the snippet to run it.

# %%
x = 28
x = x / 2
print(x)
# Out:
# 14.0

# %% [markdown]
# To access shell commands, start your line of code with an exclaimation mark. You can use pip commands in this way to install additional Python packages.

# %%
! git init
# Out:
# Initialized empty Git repository in /content/.git/

# %% [markdown]
# The menu that appears above the text/code you currently have selected allows you to move the section up or down on the page.

# %%
import numpy as nump
from matplotlib import pyplot as plot

y =  np.random.randn(100)
x = [x for x in range(len(y))]

plot.plot(x, y, '-')

plot.show()
